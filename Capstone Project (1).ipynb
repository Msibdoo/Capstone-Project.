# %% [markdown]
# # Final Capstone Project

# %%
import pandas as pd
dataset = pd.read_excel("C:/Users/User/Desktop/Excel Docs/Hostel Booking Challenge_FestMan(1).xlsx")

# %%
df = pd.DataFrame(dataset)

# %%
df.head(10)
# Out:
#   Booking ID Date of Booking  Year      Time Customer ID  Gender  Age  \
# 0  DDMY00001      2010-01-01  2010  10:49:40     MY00001    Male   42
# 1  DDID00002      2010-01-01  2010  09:19:47     ID00001  Female   44
# 2  DDSG00003      2010-01-01  2010  11:52:56     SG00001  Female   31
# 3  DDSG00004      2010-01-01  2010  13:44:40     SG00002    Male   28
# 4  DDKH00005      2010-01-01  2010  05:38:26     KH00001    Male   44
# 5  DDTH00006      2010-01-01  2010  05:41:55     TH00001    Male   32
# 6  DDTH00007      2010-01-01  2010  20:14:21     TH00002    Male   49
# 7  DDMY00008      2010-01-01  2010  00:22:07     MY00002  Female   58
# 8  DDSG00009      2010-01-01  2010  09:30:32     SG00003    Male   57
# 9  DDSG00010      2010-01-01  2010  16:22:39     SG00004  Female   41
#
#   Origin Country        State         Location  ... Check-Out Date Rooms  \
# 0       Malaysia        Johor  Iskandar Puteri  ...     2010-01-20     1
# ...

# %%
df.groupby('Destination Country')['Destination Country'].count()
# Out:
# Destination Country
# Brazil         3241
# Canada         3333
# China          3391
# Colombia       3408
# Denmark        3375
# Egypt          3423
# France         3346
# Germany        3301
# Iceland        3345
# India          3290
# Iran           3172
# Ireland        3316
# Israel         3358
# Italy          3340
# Japan          3255
# Kenya          3233
# Maldives       3267
# Mexico         3257
# Nepal          3446
# New Zealand    3447
# Name: Destination Country, dtype: int64

# %% [markdown]
# The highest is New Zealand

# %%
df.groupby('Age')['Gender'].count()
# Out:
# Age
# 19    1723
# 20    1601
# 21    1645
# 22    1776
# 23    1630
# 24    1645
# 25    1742
# 26    1651
# 27    1647
# 28    1735
# 29    1649
# 30    1653
# 31    1703
# 32    1696
# 33    1715
# 34    1688
# 35    1639
# 36    1602
# 37    1621
# 38    1704
# 39    1638
# 40    1665
# 41    1656
# 42    1585
# 43    1675
# 44    1733
# 45    1625
# 46    1724
# 47    1726
# 48    1567
# 49    1594
# 50    1651
# 51    1659
# 52    1608
# 53    1598
# 54    1672
# 55    1617
# 56    1754
# 57    1612
# 58    1720
# Name: Gender, dtype: int64

# %% [markdown]
# Age 58 had the highest number of people

# %%
df.groupby('Gender')['Location'].count()
# Out:
# Gender
# Female    33394
# Male      33150
# Name: Location, dtype: int64

# %% [markdown]
# Females made the highest booking by location

# %%
df.groupby('Hotel Name')['Hotel Rating'].count()
# Out:
# Hotel Name
# 6-Star Food Service        131
# A Homey Hearth              95
# A Pleasant Night           108
# A To B&B                   112
# A Touch of Heaven Hotel    113
#                           ...
# Woodlark                   114
# Yotel New York              94
# Zion Hotel                  91
# Zzz Motel                  101
# theWit                     100
# Name: Hotel Rating, Length: 614, dtype: int64

# %% [markdown]
# 6-Star Food Service had the highest rating

# %%
import matplotlib.pyplot as plt
import seaborn as sns
x = ['Male', 'Female']
y = [33150, 33394]
bar_plot = sns.barplot(x , y)
bar_plot.set_title('Male Vs Females')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Male Vs Females')

# %%
df.groupby('Payment Mode')['Bank Name'].count()
# Out:
# Payment Mode
# COD                 13150
# Credit Card         13266
# Debit Card          13366
# Internet Banking    13447
# Wallet              13315
# Name: Bank Name, dtype: int64

# %% [markdown]
# The Most used payment mode was Internet Banking

# %%
sns.boxplot(x = 'Year', y = 'Booking Price[SGD]',hue = 'Gender', data = df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Booking Price[SGD]'>

# %% [markdown]
# 2013 and 2018 had a wider spread with females making the maximum bbooking in 2013 and males making maximum in 2018

# %%
df.dropna()
# Out:
#         Booking ID Date of Booking  Year      Time Customer ID  Gender  Age  \
# 0        DDMY00001      2010-01-01  2010  10:49:40     MY00001    Male   42
# 1        DDID00002      2010-01-01  2010  09:19:47     ID00001  Female   44
# 2        DDSG00003      2010-01-01  2010  11:52:56     SG00001  Female   31
# 3        DDSG00004      2010-01-01  2010  13:44:40     SG00002    Male   28
# 4        DDKH00005      2010-01-01  2010  05:38:26     KH00001    Male   44
# ...            ...             ...   ...       ...         ...     ...  ...
# 66539   DDSG665890      2019-12-31  2019  23:36:16     SG12034  Female   42
# 66540   DDSG665678      2019-12-31  2019  14:41:01     SG12035  Female   54
# 66541    DDSG66324      2019-12-31  2019  19:11:16     SG12036  Female   57
# 66542  DDTH6651004      2019-12-31  2019  05:12:29     TH12170  Female   44
# 66543   DDVN665334      2019-12-31  2019  00:51:52     VN05959  Female   52
#
# ...

# %%
df.drop_duplicates()
# Out:
#         Booking ID Date of Booking  Year      Time Customer ID  Gender  Age  \
# 0        DDMY00001      2010-01-01  2010  10:49:40     MY00001    Male   42
# 1        DDID00002      2010-01-01  2010  09:19:47     ID00001  Female   44
# 2        DDSG00003      2010-01-01  2010  11:52:56     SG00001  Female   31
# 3        DDSG00004      2010-01-01  2010  13:44:40     SG00002    Male   28
# 4        DDKH00005      2010-01-01  2010  05:38:26     KH00001    Male   44
# ...            ...             ...   ...       ...         ...     ...  ...
# 66539   DDSG665890      2019-12-31  2019  23:36:16     SG12034  Female   42
# 66540   DDSG665678      2019-12-31  2019  14:41:01     SG12035  Female   54
# 66541    DDSG66324      2019-12-31  2019  19:11:16     SG12036  Female   57
# 66542  DDTH6651004      2019-12-31  2019  05:12:29     TH12170  Female   44
# 66543   DDVN665334      2019-12-31  2019  00:51:52     VN05959  Female   52
#
# ...

# %%
df['Customer ID'].count()
# Out:
# 66544

# %% [markdown]
# A total of 66544 unique customers

# %%
df
# Out:
#         Booking ID Date of Booking  Year      Time Customer ID  Gender  Age  \
# 0        DDMY00001      2010-01-01  2010  10:49:40     MY00001    Male   42
# 1        DDID00002      2010-01-01  2010  09:19:47     ID00001  Female   44
# 2        DDSG00003      2010-01-01  2010  11:52:56     SG00001  Female   31
# 3        DDSG00004      2010-01-01  2010  13:44:40     SG00002    Male   28
# 4        DDKH00005      2010-01-01  2010  05:38:26     KH00001    Male   44
# ...            ...             ...   ...       ...         ...     ...  ...
# 66539   DDSG665890      2019-12-31  2019  23:36:16     SG12034  Female   42
# 66540   DDSG665678      2019-12-31  2019  14:41:01     SG12035  Female   54
# 66541    DDSG66324      2019-12-31  2019  19:11:16     SG12036  Female   57
# 66542  DDTH6651004      2019-12-31  2019  05:12:29     TH12170  Female   44
# 66543   DDVN665334      2019-12-31  2019  00:51:52     VN05959  Female   52
#
# ...

# %%
df['Booking ID'].count()
# Out:
# 66544

# %% [markdown]
# 66544 Bookings Made

# %%
df.groupby('Year')['Booking ID'].count()
# Out:
# Year
# 2010    4797
# 2011    5309
# 2012    5607
# 2013    5525
# 2014    5905
# 2015    6292
# 2016    6212
# 2017    8571
# 2018    8816
# 2019    9510
# Name: Booking ID, dtype: int64

# %% [markdown]
# 2019 had the highest number of booking

# %%
import matplotlib.pyplot as plt
y = df.groupby('Year')['Booking ID'].count()
plt.plot(y)
plt.title('Yearly Booking Trend')
# Out:
# Text(0.5, 1.0, 'Yearly Booking Trend')
